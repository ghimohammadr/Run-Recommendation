# %%
# !pip install streamlit
# !npm install -g localtunnel
# Out:
# ...
# ⠙⠹⠸⠼⠴⠦⠧
# changed 22 packages in 941ms
# ⠧
# ⠧3 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧

# %%
# !pip install -q gdown  # Install gdown if not already installed

# Download the app3.py file from Google Drive
# !gdown --id 1X8Jn0OEqEo5YjLDEA8rqF-n0IisPQjd0 -O app3.py
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1X8Jn0OEqEo5YjLDEA8rqF-n0IisPQjd0
# From (redirected): https://drive.google.com/uc?id=1X8Jn0OEqEo5YjLDEA8rqF-n0IisPQjd0&confirm=t&uuid=96a3b0d8-beca-4ebf-bb59-e3e845f0823f
# To: /content/app3.py
# 100% 22.1k/22.1k [00:00<00:00, 18.2MB/s]

# %%
# !streamlit run app3.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.86.202.239:8501
#
# ⠹⠸⠼⠴⠦your url is: https://mean-hornets-cough.loca.lt
#   Stopping...
# ^C
